# %%
from pathlib import Path
from infrastructure.robot.fleet import get_fleet_data
from wayve.core.calibration.load_calibration import load_calibration_textproto, load_v2_textproto
from wayve.core.calibration.backcompat_support import convert_to_v2

REPO_ROOT = "/home/benjin/Development/wcs/WayveCode"
CALIBRATION_DIR = Path(REPO_ROOT) / "infrastructure" / "robot" / "config"

VEHICLES = [entry.name for entry in CALIBRATION_DIR.iterdir() if entry.is_dir()]

# %%
def get_calibration_gen1(vehicle_dir: Path, prior: bool):
    if prior:
        textproto_file = vehicle_dir / "bb" / "vehicle_calibration_default.textproto"

    else:
        textproto_file = vehicle_dir / "bb" / "vehicle_calibration.textproto"

    calib = load_calibration_textproto(textproto_file)
    calib = convert_to_v2(calib)
    
    return calib
    

def get_calibration_gen2(vehicle_dir: Path, prior: bool):
    if prior:
        textproto_file = vehicle_dir / "wayve-interfaces-protobuf-VehicleCalibration_default.textproto"
    
    else:
        textproto_file = vehicle_dir / "wayve-interfaces-protobuf-VehicleCalibration_.textproto"

    calib = load_v2_textproto(textproto_file)
    return calib

def is_gen1(vehicle_dir: Path) -> bool:
    calib_exists = (vehicle_dir / "bb" / "vehicle_calibration.textproto").exists()
    prior_calib_exists = (vehicle_dir / "bb" / "vehicle_calibration_default.textproto").exists()
    return calib_exists and prior_calib_exists

def is_gen2(vehicle_dir: Path) -> bool:
    calib_exists = (vehicle_dir / "wayve-interfaces-protobuf-VehicleCalibration_.textproto").exists()
    prior_calib_exists = (vehicle_dir / "wayve-interfaces-protobuf-VehicleCalibration_default.textproto").exists()
    return calib_exists and prior_calib_exists


def get_calibration(vehicle, prior=False):
    vehicle_dir = CALIBRATION_DIR / vehicle

    if is_gen1(vehicle_dir):
        calib = get_calibration_gen1(vehicle_dir, prior)
    elif is_gen2(vehicle_dir):
        calib = get_calibration_gen2(vehicle_dir, prior)
    else:
        print(f"Vehicle directory does not seem to be either gen1 or gen2 for {vehicle}")
        return None

    return calib

def assert_equality_serial_numbers(calib, calib_prior):
    # Check that the same sensor calibration entries exist
    calib_sensors = set(calib.sensor_calibrations.keys())
    calib_prior_sensors = set(calib_prior.sensor_calibrations.keys())
    if calib_sensors != calib_prior_sensors:
        return f"Sensor calibration entries do not match calib {calib_sensors} vs calib_prior {calib_prior_sensors}"
    
    err_msgs = []

    for sensor in calib_sensors:
        calib_sensor_serial = calib.sensor_calibrations[sensor].metadata.serial_number
        calib_prior_sensor_serial = calib_prior.sensor_calibrations[sensor].metadata.serial_number

        if calib_sensor_serial != calib_prior_sensor_serial:
            err_msgs.append(f"Serial number mismatch for sensor {sensor}: {calib_sensor_serial} vs {calib_prior_sensor_serial}")
        
    if len(err_msgs) > 0:
        return "\n" + "\n".join(err_msgs)
    
    return None

def assert_equality_camera_intrinsics(calib, calib_prior):
    # Check that the same sensor calibration entries exist
    calib_sensors = set(calib.sensor_calibrations.keys())
    calib_prior_sensors = set(calib_prior.sensor_calibrations.keys())
    if calib_sensors != calib_prior_sensors:
        return f"Sensor calibration entries do not match calib {calib_sensors} vs calib_prior {calib_prior_sensors}"
    
    err_msgs = []

    for sensor in calib_sensors:
        calib_sensor_intrinsics = calib.sensor_calibrations[sensor].camera_intrinsics
        calib_prior_sensor_intrinsics = calib_prior.sensor_calibrations[sensor].camera_intrinsics

        if calib_sensor_intrinsics.camera_geometry != calib_prior_sensor_intrinsics.camera_geometry:
            err_msgs.append(f"Camera geometry mismatch for sensor {sensor}:\n{calib_sensor_intrinsics.camera_geometry}vs\n{calib_prior_sensor_intrinsics.camera_geometry}")

        if calib_sensor_intrinsics.focal_length_px != calib_prior_sensor_intrinsics.focal_length_px:
            err_msgs.append(f"Focal length mismatch for sensor {sensor}:\n{calib_sensor_intrinsics.focal_length_px}vs\n{calib_prior_sensor_intrinsics.focal_length_px}")
        
        if calib_sensor_intrinsics.principal_point_px != calib_prior_sensor_intrinsics.principal_point_px:
            err_msgs.append(f"Principal point mismatch for sensor {sensor}:\n{calib_sensor_intrinsics.principal_point_px}vs\n{calib_prior_sensor_intrinsics.principal_point_px}")

        if calib_sensor_intrinsics.dist_coeffs[:4] != calib_prior_sensor_intrinsics.dist_coeffs[:4]:
            err_msgs.append(f"Distortion coefficients mismatch for sensor {sensor}:\n{calib_sensor_intrinsics.dist_coeffs[:4]}\nvs\n{calib_prior_sensor_intrinsics.dist_coeffs[:4]}")

    if len(err_msgs) > 0:
        return "\n" + "\n".join(err_msgs)
    
    return None

problematic_vehicles = []

for vehicle in VEHICLES:

    print(f"////////////////////////////////{vehicle}////////////////////////////////")

    calib = get_calibration(vehicle, prior=False)
    calib_prior = get_calibration(vehicle, prior=True)

    if calib is None or calib_prior is None:
        continue

    err_sn = assert_equality_serial_numbers(calib, calib_prior)
    if err_sn is not None:
        print(f"In assert_equality_serial_numbers for {vehicle} got error: {err_sn}")

    err_intr = assert_equality_camera_intrinsics(calib, calib_prior)
    if err_intr is not None:
        print(f"In assert_equality_camera_intrinsics for {vehicle} got error: {err_intr}")
    
    if err_sn is not None or err_intr is not None:
        problematic_vehicles.append(vehicle)
# Out:
# ////////////////////////////////avon////////////////////////////////
# In assert_equality_camera_intrinsics for avon got error:
# Focal length mismatch for sensor back-left-leftward:
# x: 1145.6
# y: 1143.8
# vs
# x: 1144.41748
# y: 1142.89929
#
# Principal point mismatch for sensor back-left-leftward:
# x: 1010.9
# y: 640.23
# vs
# x: 1015.80499
# y: 645.220703
#
# Distortion coefficients mismatch for sensor back-left-leftward:
# [-0.019493, -0.055636, 0.049564, -0.018839]
# vs
# [-0.01721392, -0.05743259, 0.04944835, -0.01848868]
# Focal length mismatch for sensor back-right-rightward:
# x: 1147.9
# y: 1146.3
# vs
# x: 1144.41748
# y: 1142.89929
#
# Principal point mismatch for sensor back-right-rightward:
# x: 1009.8
# y: 641.11
# vs
# x: 1015.80499
# y: 645.220703
#
# Distortion coefficients mismatch for sensor back-right-rightward:
# [-0.013371, -0.065532, 0.054222, -0.019]
# vs
# [-0.01721392, -0.05743259, 0.04944835, -0.01848868]
# Focal length mismatch for sensor front-left-leftward:
# x: 1140.7
# y: 1138.9
# vs
# x: 1144.41748
# y: 1142.89929
#
# Principal point mismatch for sensor front-left-leftward:
# x: 1009.9
# y: 640.94
# vs
# x: 1015.80499
# y: 645.220703
#
# Distortion coefficients mismatch for sensor front-left-leftward:
# [-0.014217, -0.067242, 0.060119, -0.022289]
# vs
# [-0.01721392, -0.05743259, 0.04944835, -0.01848868]
# Focal length mismatch for sensor front-right-rightward:
# x: 1144.1
# y: 1142.4
# vs
# x: 1144.41748
# y: 1142.89929
#
# Principal point mismatch for sensor front-right-rightward:
# x: 1011
# y: 645.1
# vs
# x: 1015.80499
# y: 645.220703
#
# Distortion coefficients mismatch for sensor front-right-rightward:
# [-0.010276, -0.073167, 0.063311, -0.02276]
# vs
# [-0.01721392, -0.05743259, 0.04944835, -0.01848868]
# Focal length mismatch for sensor front-forward:
# x: 1145.5
# y: 1144
# vs
# x: 1144.41748
# y: 1142.89929
#
# Principal point mismatch for sensor front-forward:
# x: 1008.7
# y: 640.93
# vs
# x: 1015.80499
# y: 645.220703
#
# Distortion coefficients mismatch for sensor front-forward:
# [-0.004426, -0.085665, 0.074847, -0.026497]
# vs
# [-0.01721392, -0.05743259, 0.04944835, -0.01848868]
# ////////////////////////////////benchy////////////////////////////////
# Vehicle directory does not seem to be either gen1 or gen2 for benchy
# Vehicle directory does not seem to be either gen1 or gen2 for benchy
# ////////////////////////////////beni////////////////////////////////
# In assert_equality_camera_intrinsics for beni got error:
# Focal length mismatch for sensor back-left-leftward:
# x: 1142.54858
# y: 1140.43286
# vs
# x: 1144.41748
# y: 1142.89929
#
# Principal point mismatch for sensor back-left-leftward:
# x: 1019.26477
# y: 647.272156
# vs
# x: 1015.80499
# y: 645.220703
#
# Distortion coefficients mismatch for sensor back-left-leftward:
# [-0.012098, -0.067405, 0.056869, -0.020372]
# vs
# [-0.01721392, -0.05743259, 0.04944835, -0.01848868]
# Focal length mismatch for sensor back-right-rightward:
# x: 1145.11328
# y: 1142.94775
# vs
# x: 1144.41748
# y: 1142.89929
#
# Principal point mismatch for sensor back-right-rightward:
# x: 1008.71948
# y: 633.422729
# vs
# x: 1015.80499
# y: 645.220703
#
# Distortion coefficients mismatch for sensor back-right-rightward:
# [-0.024506, -0.040898, 0.033435, -0.013014]
# vs
# [-0.01721392, -0.05743259, 0.04944835, -0.01848868]
# Focal length mismatch for sensor front-left-leftward:
# x: 1145.89709
# y: 1143.51917
# vs
# x: 1144.41748
# y: 1142.89929
#
# Principal point mismatch for sensor front-left-leftward:
# x: 1008.37207
# y: 637.904114
# vs
# x: 1015.80499
# y: 645.220703
#
# Distortion coefficients mismatch for sensor front-left-leftward:
# [-0.022897, -0.044025, 0.036422, -0.014115]
# vs
# [-0.01721392, -0.05743259, 0.04944835, -0.01848868]
# Focal length mismatch for sensor front-right-rightward:
# x: 1143.59241
# y: 1141.31433
# vs
# x: 1144.41748
# y: 1142.89929
#
# Principal point mismatch for sensor front-right-rightward:
# x: 1019.78815
# y: 645.010559
# vs
# x: 1015.80499
# y: 645.220703
#
# Distortion coefficients mismatch for sensor front-right-rightward:
# [-0.018311, -0.055717, 0.04898, -0.018778]
# vs
# [-0.01721392, -0.05743259, 0.04944835, -0.01848868]
# Focal length mismatch for sensor front-forward:
# x: 1145.67285
# y: 1143.27466
# vs
# x: 1144.41748
# y: 1142.89929
#
# Principal point mismatch for sensor front-forward:
# x: 1009.15381
# y: 644.801086
# vs
# x: 1015.80499
# y: 645.220703
#
# Distortion coefficients mismatch for sensor front-forward:
# [-0.022948, -0.047467, 0.041559, -0.016166]
# vs
# [-0.01721392, -0.05743259, 0.04944835, -0.01848868]
# ////////////////////////////////brizo////////////////////////////////
# In assert_equality_serial_numbers for brizo got error: Sensor calibration entries do not match calib {'back-backward', 'back-left-leftward', 'imu', 'back-right-rightward', 'front-left-leftward', 'front-right-rightward', 'front-forward'} vs calib_prior {'back-backward', 'back-left-leftward', 'imu', 'lidar', 'back-right-rightward', 'front-left-leftward', 'front-right-rightward', 'front-forward'}
# In assert_equality_camera_intrinsics for brizo got error: Sensor calibration entries do not match calib {'back-backward', 'back-left-leftward', 'imu', 'back-right-rightward', 'front-left-leftward', 'front-right-rightward', 'front-forward'} vs calib_prior {'back-backward', 'back-left-leftward', 'imu', 'lidar', 'back-right-rightward', 'front-left-leftward', 'front-right-rightward', 'front-forward'}
# ////////////////////////////////congo////////////////////////////////
# In assert_equality_camera_intrinsics for congo got error:
# Focal length mismatch for sensor back-left-leftward:
# x: 1146.43372
# y: 1144.42749
# vs
# x: 1144.41748
# y: 1142.89929
#
# Principal point mismatch for sensor back-left-leftward:
# x: 1027.62073
# y: 647.848145
# vs
# x: 1015.80499
# y: 645.220703
#
# Distortion coefficients mismatch for sensor back-left-leftward:
# [-0.018837, -0.055746, 0.050219, -0.019805]
# vs
# [-0.01721392, -0.05743259, 0.04944835, -0.01848868]
# Focal length mismatch for sensor back-right-rightward:
# x: 1148.7738
# y: 1146.77734
# vs
# x: 1144.41748
# y: 1142.89929
#
# Principal point mismatch for sensor back-right-rightward:
# x: 1016.81213
# y: 641.578735
# vs
# x: 1015.80499
# y: 645.220703
#
# Distortion coefficients mismatch for sensor back-right-rightward:
# [-0.020026, -0.056047, 0.052434, -0.021408]
# vs
# [-0.01721392, -0.05743259, 0.04944835, -0.01848868]
# Focal length mismatch for sensor front-left-leftward:
# x: 1144.68262
# y: 1142.41528
# vs
# x: 1144.41748
# y: 1142.89929
#
# Principal point mismatch for sensor front-left-leftward:
# x: 1022.75153
# y: 653.755859
# vs
# x: 1015.80499
# y: 645.220703
#
# Distortion coefficients mismatch for sensor front-left-leftward:
# [-0.023149, -0.047444, 0.043057, -0.017594]
# vs
# [-0.01721392, -0.05743259, 0.04944835, -0.01848868]
# Focal length mismatch for sensor front-right-rightward:
# x: 1149.03223
# y: 1146.46167
# vs
# x: 1144.41748
# y: 1142.89929
#
# Principal point mismatch for sensor front-right-rightward:
# x: 1023.19586
# y: 641.360168
# vs
# x: 1015.80499
# y: 645.220703
#
# Distortion coefficients mismatch for sensor front-right-rightward:
# [-0.023928, -0.046474, 0.042186, -0.01716]
# vs
# [-0.01721392, -0.05743259, 0.04944835, -0.01848868]
# Focal length mismatch for sensor front-forward:
# x: 1147.20032
# y: 1145.36279
# vs
# x: 1144.41748
# y: 1142.89929
#
# Principal point mismatch for sensor front-forward:
# x: 1020.63879
# y: 641.279663
# vs
# x: 1015.80499
# y: 645.220703
#
# Distortion coefficients mismatch for sensor front-forward:
# [-0.012969, -0.064447, 0.052639, -0.018351]
# vs
# [-0.01721392, -0.05743259, 0.04944835, -0.01848868]
# ////////////////////////////////danube////////////////////////////////
# ////////////////////////////////darling////////////////////////////////
# ////////////////////////////////ebisu////////////////////////////////
# In assert_equality_serial_numbers for ebisu got error: Sensor calibration entries do not match calib {'back-backward', 'back-left-leftward', 'imu', 'back-right-rightward', 'front-left-leftward', 'front-right-rightward', 'front-forward'} vs calib_prior {'back-backward', 'back-left-leftward', 'imu', 'lidar', 'back-right-rightward', 'front-left-leftward', 'front-right-rightward', 'front-forward'}
# In assert_equality_camera_intrinsics for ebisu got error: Sensor calibration entries do not match calib {'back-backward', 'back-left-leftward', 'imu', 'back-right-rightward', 'front-left-leftward', 'front-right-rightward', 'front-forward'} vs calib_prior {'back-backward', 'back-left-leftward', 'imu', 'lidar', 'back-right-rightward', 'front-left-leftward', 'front-right-rightward', 'front-forward'}
# ////////////////////////////////ganges////////////////////////////////
# In assert_equality_camera_intrinsics for ganges got error:
# Focal length mismatch for sensor right-backward:
# x: 897.811646
# y: 912.03418
# vs
# x: 925.55835
# y: 924.588806
#
# Principal point mismatch for sensor right-backward:
# x: 953.637146
# y: 528.43634
# vs
# x: 963.041
# y: 557.443481
#
# Distortion coefficients mismatch for sensor right-backward:
# [-9.486564522376284e-05, 0.0015465987380594015, 0.0018212830182164907, -0.0035750807728618383]
# vs
# [-0.01771651953458786, 0.0007990244193933904, 0.0037476469296962023, -0.001952857943251729]
# Focal length mismatch for sensor left-forward:
# x: 937.093628
# y: 921.894226
# vs
# x: 929.736633
# y: 928.787292
#
# Principal point mismatch for sensor left-forward:
# x: 956.889771
# y: 531.914
# vs
# x: 966.813416
# y: 553.950562
#
# Distortion coefficients mismatch for sensor left-forward:
# [-0.02166534960269928, 0.0016209131572395563, 0.0017490594182163477, -0.0024766079150140285]
# vs
# [-0.02173824980854988, 0.0016312110237777233, 0.004638640210032463, -0.0027578289154917]
# Focal length mismatch for sensor left-backward:
# x: 925.764771
# y: 914.764
# vs
# x: 925.669922
# y: 924.785828
#
# Principal point mismatch for sensor left-backward:
# x: 959.371033
# y: 526.362854
# vs
# x: 962.710266
# y: 553.491272
#
# Distortion coefficients mismatch for sensor left-backward:
# [-0.025136711075901985, 0.007196346763521433, 0.0008915383368730545, -0.0029409320559352636]
# vs
# [-0.019735809415578842, 0.003596625989302993, 0.0005027363076806068, -0.0006874267710372806]
# Focal length mismatch for sensor right-forward:
# x: 937.62262
# y: 922.007385
# vs
# x: 925.27655
# y: 924.358154
#
# Principal point mismatch for sensor right-forward:
# x: 954.393127
# y: 528.864685
# vs
# x: 964.353333
# y: 555.545105
#
# Distortion coefficients mismatch for sensor right-forward:
# [-0.01644160784780979, -0.00899224542081356, 0.012571170926094055, -0.006980526726692915]
# vs
# [-0.020843159407377243, 0.006415927782654762, -0.003181152045726776, 0.0011011030292138457]
# Focal length mismatch for sensor front-forward:
# x: 1593.98499
# y: 1560.66699
# vs
# x: 1563.23376
# y: 1561.16492
#
# Principal point mismatch for sensor front-forward:
# x: 959.788757
# y: 543.623901
# vs
# x: 954.771912
# y: 521.215698
#
# Distortion coefficients mismatch for sensor front-forward:
# [0.004891709890216589, -0.03966793417930603, 0.05079825595021248, -0.1360769122838974]
# vs
# [0.018172720447182655, -0.06491144001483917, 0.18327850103378296, -0.3176175057888031]
# ////////////////////////////////golders////////////////////////////////
# ////////////////////////////////highgate////////////////////////////////
# ////////////////////////////////hil////////////////////////////////
# ////////////////////////////////hudson////////////////////////////////
# In assert_equality_serial_numbers for hudson got error: Sensor calibration entries do not match calib {'right-backward', 'left-forward', 'left-leftward', 'imu-right', 'radar-front-forward', 'left-backward', 'right-rightward', 'imu-left', 'right-forward', 'front-forward'} vs calib_prior {'lidar-right-forward', 'right-backward', 'left-forward', 'left-leftward', 'imu-right', 'radar-front-forward', 'lidar-left-forward', 'left-backward', 'right-rightward', 'imu-left', 'rear-axle', 'right-forward', 'front-forward'}
# In assert_equality_camera_intrinsics for hudson got error: Sensor calibration entries do not match calib {'right-backward', 'left-forward', 'left-leftward', 'imu-right', 'radar-front-forward', 'left-backward', 'right-rightward', 'imu-left', 'right-forward', 'front-forward'} vs calib_prior {'lidar-right-forward', 'right-backward', 'left-forward', 'left-leftward', 'imu-right', 'radar-front-forward', 'lidar-left-forward', 'left-backward', 'right-rightward', 'imu-left', 'rear-axle', 'right-forward', 'front-forward'}
# ////////////////////////////////moose////////////////////////////////
# ////////////////////////////////nammu////////////////////////////////
# In assert_equality_serial_numbers for nammu got error: Sensor calibration entries do not match calib {'back-backward', 'back-left-leftward', 'imu', 'back-right-rightward', 'front-left-leftward', 'front-right-rightward', 'front-forward'} vs calib_prior {'back-backward', 'back-left-leftward', 'imu', 'lidar', 'back-right-rightward', 'front-left-leftward', 'front-right-rightward', 'front-forward'}
# In assert_equality_camera_intrinsics for nammu got error: Sensor calibration entries do not match calib {'back-backward', 'back-left-leftward', 'imu', 'back-right-rightward', 'front-left-leftward', 'front-right-rightward', 'front-forward'} vs calib_prior {'back-backward', 'back-left-leftward', 'imu', 'lidar', 'back-right-rightward', 'front-left-leftward', 'front-right-rightward', 'front-forward'}
# ////////////////////////////////neptune////////////////////////////////
# In assert_equality_serial_numbers for neptune got error:
# Serial number mismatch for sensor back-backward: 070100841115 vs
# Serial number mismatch for sensor back-left-leftward: 070101881159 vs
# Serial number mismatch for sensor back-right-rightward: 070100591159 vs
# Serial number mismatch for sensor front-left-leftward: 070101961159 vs
# Serial number mismatch for sensor front-right-rightward: 070100341159 vs
# Serial number mismatch for sensor front-forward: 070100571150 vs
# In assert_equality_camera_intrinsics for neptune got error:
# Focal length mismatch for sensor back-backward:
# x: 1145.17603
# y: 1143.27014
# vs
# x: 1144.41748
# y: 1142.89929
#
# Principal point mismatch for sensor back-backward:
# x: 1023.46387
# y: 647.523376
# vs
# x: 1015.80499
# y: 645.220703
#
# Distortion coefficients mismatch for sensor back-backward:
# [-0.019658, -0.054038, 0.048705, -0.019141]
# vs
# [-0.01721392, -0.05743259, 0.04944835, -0.01848868]
# Focal length mismatch for sensor back-left-leftward:
# x: 1146.34021
# y: 1144.1416
# vs
# x: 1144.41748
# y: 1142.89929
#
# Principal point mismatch for sensor back-left-leftward:
# x: 1023.5094
# y: 650.948181
# vs
# x: 1015.80499
# y: 645.220703
#
# Distortion coefficients mismatch for sensor back-left-leftward:
# [-0.021254, -0.05004, 0.043302, -0.016532]
# vs
# [-0.01721392, -0.05743259, 0.04944835, -0.01848868]
# Focal length mismatch for sensor back-right-rightward:
# x: 1147.26819
# y: 1145.41467
# vs
# x: 1144.41748
# y: 1142.89929
#
# Principal point mismatch for sensor back-right-rightward:
# x: 1026.06287
# y: 648.552368
# vs
# x: 1015.80499
# y: 645.220703
#
# Distortion coefficients mismatch for sensor back-right-rightward:
# [-0.017805, -0.055643, 0.046359, -0.016893]
# vs
# [-0.01721392, -0.05743259, 0.04944835, -0.01848868]
# Focal length mismatch for sensor front-left-leftward:
# x: 1144.71704
# y: 1142.81274
# vs
# x: 1144.41748
# y: 1142.89929
#
# Principal point mismatch for sensor front-left-leftward:
# x: 1016.82867
# y: 645.960388
# vs
# x: 1015.80499
# y: 645.220703
#
# Distortion coefficients mismatch for sensor front-left-leftward:
# [-0.021558, -0.046391, 0.037434, -0.013852]
# vs
# [-0.01721392, -0.05743259, 0.04944835, -0.01848868]
# Focal length mismatch for sensor front-right-rightward:
# x: 1148.38342
# y: 1146.36426
# vs
# x: 1144.41748
# y: 1142.89929
#
# Principal point mismatch for sensor front-right-rightward:
# x: 1013.63336
# y: 652.967712
# vs
# x: 1015.80499
# y: 645.220703
#
# Distortion coefficients mismatch for sensor front-right-rightward:
# [-0.0193, -0.055245, 0.050108, -0.019803]
# vs
# [-0.01721392, -0.05743259, 0.04944835, -0.01848868]
# Focal length mismatch for sensor front-forward:
# x: 1145.35132
# y: 1143.33887
# vs
# x: 1144.41748
# y: 1142.89929
#
# Principal point mismatch for sensor front-forward:
# x: 1011.94769
# y: 644.975891
# vs
# x: 1015.80499
# y: 645.220703
#
# Distortion coefficients mismatch for sensor front-forward:
# [-0.01576, -0.059108, 0.049605, -0.018126]
# vs
# [-0.01721392, -0.05743259, 0.04944835, -0.01848868]
# ////////////////////////////////nereus////////////////////////////////
# In assert_equality_serial_numbers for nereus got error:
# Serial number mismatch for sensor back-backward: 070101781159 vs
# Serial number mismatch for sensor back-left-leftward: 070101361159 vs
# Serial number mismatch for sensor back-right-rightward: 070101641159 vs
# Serial number mismatch for sensor front-left-leftward: 070101751159 vs
# Serial number mismatch for sensor front-right-rightward: 070101731159 vs
# Serial number mismatch for sensor front-forward: 070100431150 vs
# In assert_equality_camera_intrinsics for nereus got error:
# Focal length mismatch for sensor back-backward:
# x: 1151.30261
# y: 1149.13403
# vs
# x: 1144.41748
# y: 1142.89929
#
# Principal point mismatch for sensor back-backward:
# x: 1015.52429
# y: 638.927917
# vs
# x: 1015.80499
# y: 645.220703
#
# Distortion coefficients mismatch for sensor back-backward:
# [-0.019689, -0.050897, 0.041702, -0.015569]
# vs
# [-0.01721392, -0.05743259, 0.04944835, -0.01848868]
# Focal length mismatch for sensor back-left-leftward:
# x: 1144.42151
# y: 1142.11267
# vs
# x: 1144.41748
# y: 1142.89929
#
# Principal point mismatch for sensor back-left-leftward:
# x: 1013.16779
# y: 651.187805
# vs
# x: 1015.80499
# y: 645.220703
#
# Distortion coefficients mismatch for sensor back-left-leftward:
# [-0.017965, -0.060078, 0.054423, -0.020869]
# vs
# [-0.01721392, -0.05743259, 0.04944835, -0.01848868]
# Focal length mismatch for sensor back-right-rightward:
# x: 1145.76855
# y: 1143.37659
# vs
# x: 1144.41748
# y: 1142.89929
#
# Principal point mismatch for sensor back-right-rightward:
# x: 1014.5285
# y: 641.726
# vs
# x: 1015.80499
# y: 645.220703
#
# Distortion coefficients mismatch for sensor back-right-rightward:
# [-0.018103, -0.060007, 0.055053, -0.021594]
# vs
# [-0.01721392, -0.05743259, 0.04944835, -0.01848868]
# Focal length mismatch for sensor front-left-leftward:
# x: 1145.18738
# y: 1143.00281
# vs
# x: 1144.41748
# y: 1142.89929
#
# Principal point mismatch for sensor front-left-leftward:
# x: 1011.43823
# y: 652.507568
# vs
# x: 1015.80499
# y: 645.220703
#
# Distortion coefficients mismatch for sensor front-left-leftward:
# [-0.017263, -0.062541, 0.059808, -0.024131]
# vs
# [-0.01721392, -0.05743259, 0.04944835, -0.01848868]
# Focal length mismatch for sensor front-right-rightward:
# x: 1145.31689
# y: 1142.99622
# vs
# x: 1144.41748
# y: 1142.89929
#
# Principal point mismatch for sensor front-right-rightward:
# x: 1015.02686
# y: 639.201355
# vs
# x: 1015.80499
# y: 645.220703
#
# Distortion coefficients mismatch for sensor front-right-rightward:
# [-0.021499, -0.046506, 0.037008, -0.013468]
# vs
# [-0.01721392, -0.05743259, 0.04944835, -0.01848868]
# Focal length mismatch for sensor front-forward:
# x: 1146.69885
# y: 1144.71594
# vs
# x: 1144.41748
# y: 1142.89929
#
# Principal point mismatch for sensor front-forward:
# x: 1020.15033
# y: 658.541565
# vs
# x: 1015.80499
# y: 645.220703
#
# Distortion coefficients mismatch for sensor front-forward:
# [-0.011547, -0.072877, 0.06603, -0.024769]
# vs
# [-0.01721392, -0.05743259, 0.04944835, -0.01848868]
# ////////////////////////////////orinoco////////////////////////////////
# ////////////////////////////////oya////////////////////////////////
# In assert_equality_serial_numbers for oya got error: Sensor calibration entries do not match calib {'back-backward', 'back-left-leftward', 'imu', 'back-right-rightward', 'front-left-leftward', 'front-right-rightward', 'front-forward'} vs calib_prior {'back-backward', 'back-left-leftward', 'imu', 'lidar', 'back-right-rightward', 'front-left-leftward', 'front-right-rightward', 'front-forward'}
# In assert_equality_camera_intrinsics for oya got error: Sensor calibration entries do not match calib {'back-backward', 'back-left-leftward', 'imu', 'back-right-rightward', 'front-left-leftward', 'front-right-rightward', 'front-forward'} vs calib_prior {'back-backward', 'back-left-leftward', 'imu', 'lidar', 'back-right-rightward', 'front-left-leftward', 'front-right-rightward', 'front-forward'}
# ////////////////////////////////po////////////////////////////////
# In assert_equality_camera_intrinsics for po got error:
# Focal length mismatch for sensor left-forward:
# x: 1822.38416
# y: 1820.19153
# vs
# x: 1820.55615
# y: 1818.45154
#
# Principal point mismatch for sensor left-forward:
# x: 1911.86792
# y: 1051.01416
# vs
# x: 1910.71533
# y: 1052.01062
#
# Distortion coefficients mismatch for sensor left-forward:
# [-0.0147409001365304, -1.940671972988639e-05, 0.011882539838552475, -0.009308603592216969]
# vs
# [0.8807289, 0.1620152, 0.0008867284, 1.229197]
# Focal length mismatch for sensor left-leftward:
# x: 910.941345
# y: 909.805054
# vs
# x: 910.387878
# y: 909.292175
#
# Principal point mismatch for sensor left-leftward:
# x: 959.510864
# y: 527.233276
# vs
# x: 959.216614
# y: 526.451538
#
# Distortion coefficients mismatch for sensor left-leftward:
# [-0.015644799917936325, 0.004002783913165331, 0.00667126988992095, -0.007286258041858673]
# vs
# [1.108001, 0.1343244, -0.01560185, 1.456553]
# Focal length mismatch for sensor right-rightward:
# x: 921.271545
# y: 920.167358
# vs
# x: 920.421631
# y: 919.346252
#
# Principal point mismatch for sensor right-rightward:
# x: 955.323059
# y: 525.344177
# vs
# x: 955.473694
# y: 524.405212
#
# Distortion coefficients mismatch for sensor right-rightward:
# [-0.020313460379838943, 0.0005897078081034124, 0.012317799963057041, -0.009544429369270802]
# vs
# [0.7747516, 0.0648717, -0.006475407, 1.128722]
# Focal length mismatch for sensor right-forward:
# x: 1826.86694
# y: 1824.55847
# vs
# x: 1826.10535
# y: 1823.74719
#
# Principal point mismatch for sensor right-forward:
# x: 1903.01807
# y: 1055.30408
# vs
# x: 1905.03027
# y: 1056.2384
#
# Distortion coefficients mismatch for sensor right-forward:
# [-0.01480180025100708, 0.0031763738952577114, 0.00412487518042326, -0.003988843876868486]
# vs
# [0.861313, -0.03533613, -0.01842369, 1.21037]
# Focal length mismatch for sensor front-forward:
# x: 3170.22046
# y: 3165.50732
# vs
# x: 3120.92212
# y: 3116.95654
#
# Principal point mismatch for sensor front-forward:
# x: 1909.91052
# y: 1041.63855
# vs
# x: 1920.44177
# y: 1035.25696
#
# Distortion coefficients mismatch for sensor front-forward:
# [0.004453395958989859, 0.0027692250441759825, -0.019339660182595253, -0.1235705018043518]
# vs
# [-23.92554, 160.4652, 19.79303, -23.6172]
# ////////////////////////////////poseidon////////////////////////////////
# In assert_equality_serial_numbers for poseidon got error: Sensor calibration entries do not match calib {'back-backward', 'back-left-leftward', 'imu', 'back-right-rightward', 'front-left-leftward', 'front-right-rightward', 'front-forward'} vs calib_prior {'back-backward', 'back-left-leftward', 'imu', 'lidar', 'back-right-rightward', 'front-left-leftward', 'front-right-rightward', 'front-forward'}
# In assert_equality_camera_intrinsics for poseidon got error: Sensor calibration entries do not match calib {'back-backward', 'back-left-leftward', 'imu', 'back-right-rightward', 'front-left-leftward', 'front-right-rightward', 'front-forward'} vs calib_prior {'back-backward', 'back-left-leftward', 'imu', 'lidar', 'back-right-rightward', 'front-left-leftward', 'front-right-rightward', 'front-forward'}
# ////////////////////////////////primrose////////////////////////////////
# ////////////////////////////////richmond////////////////////////////////
# ////////////////////////////////sedna////////////////////////////////
# In assert_equality_serial_numbers for sedna got error: Sensor calibration entries do not match calib {'back-backward', 'back-left-leftward', 'imu', 'back-right-rightward', 'front-left-leftward', 'front-right-rightward', 'front-forward'} vs calib_prior {'back-backward', 'back-left-leftward', 'imu', 'lidar', 'back-right-rightward', 'front-left-leftward', 'front-right-rightward', 'front-forward'}
# In assert_equality_camera_intrinsics for sedna got error: Sensor calibration entries do not match calib {'back-backward', 'back-left-leftward', 'imu', 'back-right-rightward', 'front-left-leftward', 'front-right-rightward', 'front-forward'} vs calib_prior {'back-backward', 'back-left-leftward', 'imu', 'lidar', 'back-right-rightward', 'front-left-leftward', 'front-right-rightward', 'front-forward'}
# ////////////////////////////////shared////////////////////////////////
# Vehicle directory does not seem to be either gen1 or gen2 for shared
# Vehicle directory does not seem to be either gen1 or gen2 for shared
# ////////////////////////////////shire////////////////////////////////
# In assert_equality_camera_intrinsics for shire got error:
# Focal length mismatch for sensor right-backward:
# x: 921.214844
# y: 916.703918
# vs
# x: 936.644592
# y: 932.451782
#
# Principal point mismatch for sensor right-backward:
# x: 959.793
# y: 564.016785
# vs
# x: 965.422119
# y: 558.95459
#
# Distortion coefficients mismatch for sensor right-backward:
# [-0.025489, 0.016204, -0.014643, 0.004271]
# vs
# [-0.054188, 0.058224, -0.043497, 0.012559]
# Focal length mismatch for sensor left-forward:
# x: 1810.92126
# y: 1806.47888
# vs
# x: 1885.0459
# y: 1877.51294
#
# Principal point mismatch for sensor left-forward:
# x: 1930.40125
# y: 1092.32166
# vs
# x: 1934.31
# y: 1091.55603
#
# Distortion coefficients mismatch for sensor left-forward:
# [-0.012951, -0.006774, 0.008466, -0.003089]
# vs
# [-0.03055725, 0.015429, -0.00837125, 0.00138525]
# Focal length mismatch for sensor left-leftward:
# x: 925.115967
# y: 921.419373
# vs
# x: 937.565674
# y: 935.755615
#
# Principal point mismatch for sensor left-leftward:
# x: 968.182739
# y: 545.368286
# vs
# x: 958.927917
# y: 542.81134
#
# Distortion coefficients mismatch for sensor left-leftward:
# [-0.010079, -0.028784, 0.030451, -0.010214]
# vs
# [-0.026734, 0.011487, -0.008395, 0.002311]
# Focal length mismatch for sensor left-backward:
# x: 925.115967
# y: 921.419373
# vs
# x: 929.145508
# y: 928.295898
#
# Principal point mismatch for sensor left-backward:
# x: 968.182739
# y: 545.368286
# vs
# x: 958.806
# y: 551.786316
#
# Distortion coefficients mismatch for sensor left-backward:
# [-0.010079, -0.028784, 0.030451, -0.010214]
# vs
# [-0.019148, 0.00427, 0.000204, -0.0023]
# Focal length mismatch for sensor right-rightward:
# x: 931.670959
# y: 927.679749
# vs
# x: 931.757446
# y: 931.298279
#
# Principal point mismatch for sensor right-rightward:
# x: 970.033325
# y: 537.007263
# vs
# x: 963.861572
# y: 536.976196
#
# Distortion coefficients mismatch for sensor right-rightward:
# [-0.023267, -0.00615, 0.01168, -0.004156]
# vs
# [-0.035027, 0.022651, -0.013928, 0.003236]
# Focal length mismatch for sensor right-forward:
# x: 1743.32922
# y: 1734.76379
# vs
# x: 1885.0459
# y: 1877.51294
#
# Principal point mismatch for sensor right-forward:
# x: 1948.97803
# y: 1069.09717
# vs
# x: 1934.31
# y: 1091.55603
#
# Distortion coefficients mismatch for sensor right-forward:
# [-0.006667, 0.033284, -0.031545, 0.00918]
# vs
# [-0.03055725, 0.015429, -0.00837125, 0.00138525]
# Focal length mismatch for sensor front-forward:
# x: 3079.33691
# y: 3061.0979
# vs
# x: 3312.03857
# y: 3303.15747
#
# Principal point mismatch for sensor front-forward:
# x: 2022.24255
# y: 1051.3988
# vs
# x: 1937.49438
# y: 1066.53088
#
# Distortion coefficients mismatch for sensor front-forward:
# [-0.008682, 0.113756, -0.370129, 0.317664]
# vs
# [0.011322, 0.065734, -0.473847, 0.603944]
# ////////////////////////////////test////////////////////////////////
# Vehicle directory does not seem to be either gen1 or gen2 for test
# Vehicle directory does not seem to be either gen1 or gen2 for test
# ////////////////////////////////thames////////////////////////////////
# In assert_equality_camera_intrinsics for thames got error:
# Focal length mismatch for sensor right-backward:
# x: 917.463562
# y: 915.899109
# vs
# x: 926.82666
# y: 926.089478
#
# Principal point mismatch for sensor right-backward:
# x: 953.512817
# y: 527.321899
# vs
# x: 970.711426
# y: 555.199707
#
# Distortion coefficients mismatch for sensor right-backward:
# [-0.018754199147224426, 0.008614083752036095, 0.0020211536902934313, -0.003005875274538994]
# vs
# [-0.020015660673379898, 0.0005817040801048279, 0.007580492179840803, -0.005454719997942448]
# Focal length mismatch for sensor left-forward:
# x: 931.617188
# y: 931.733154
# vs
# x: 931.029846
# y: 930.11731
#
# Principal point mismatch for sensor left-forward:
# x: 957.241516
# y: 530.295837
# vs
# x: 963.804321
# y: 552.311707
#
# Distortion coefficients mismatch for sensor left-forward:
# [-0.024891261011362076, 0.0060843899846076965, -0.0002619877632241696, -0.0010360284941270947]
# vs
# [-0.021850770339369774, 0.0017513299826532602, 0.0046452721580863, -0.002942634979262948]
# Focal length mismatch for sensor left-backward:
# x: 926.716125
# y: 928.632385
# vs
# x: 907.477417
# y: 906.516968
#
# Principal point mismatch for sensor left-backward:
# x: 953.464844
# y: 527.735046
# vs
# x: 966.12207
# y: 553.451904
#
# Distortion coefficients mismatch for sensor left-backward:
# [-0.020839093253016472, 0.003194461576640606, 0.0002167893690057099, -0.0006177983013913035]
# vs
# [-0.011542930267751217, -0.004332087002694607, 0.01646965928375721, -0.011378680355846882]
# Focal length mismatch for sensor right-forward:
# x: 929.175232
# y: 929.212769
# vs
# x: 927.339722
# y: 926.366882
#
# Principal point mismatch for sensor right-forward:
# x: 954.439209
# y: 530.010864
# vs
# x: 966.128723
# y: 553.310242
#
# Distortion coefficients mismatch for sensor right-forward:
# [-0.021243920549750328, 0.0018968803342431784, 0.0022488588001579046, -0.0016972206067293882]
# vs
# [-0.021549679338932037, 0.004396914038807154, -9.203560330206528e-05, -0.000369728310033679]
# Focal length mismatch for sensor front-forward:
# x: 1584.22009
# y: 1580.8335
# vs
# x: 1570.3468
# y: 1568.65137
#
# Principal point mismatch for sensor front-forward:
# x: 964.385
# y: 544.460266
# vs
# x: 946.749084
# y: 514.764282
#
# Distortion coefficients mismatch for sensor front-forward:
# [0.012675744481384754, -0.05415811762213707, 0.0867675244808197, -0.14854122698307037]
# vs
# [0.01639961078763008, -0.053574901074171066, 0.1292629987001419, -0.2482800930738449]
# ////////////////////////////////test_defaults////////////////////////////////
# ////////////////////////////////ci_test////////////////////////////////
# Vehicle directory does not seem to be either gen1 or gen2 for ci_test
# Vehicle directory does not seem to be either gen1 or gen2 for ci_test
# ////////////////////////////////jordan////////////////////////////////
# ////////////////////////////////lbn00001////////////////////////////////
# ////////////////////////////////mbn00002////////////////////////////////
# ////////////////////////////////mbn00003////////////////////////////////
# ////////////////////////////////mekong////////////////////////////////
# In assert_equality_camera_intrinsics for mekong got error:
# Focal length mismatch for sensor right-backward:
# x: 906.591431
# y: 920.028
# vs
# x: 930.264587
# y: 929.327209
#
# Principal point mismatch for sensor right-backward:
# x: 943.520935
# y: 526.796875
# vs
# x: 964.416931
# y: 555.745422
#
# Distortion coefficients mismatch for sensor right-backward:
# [-0.020958762615919113, 0.010684279724955559, -0.0008582707378081977, -0.005964579991996288]
# vs
# [-0.01845218986272812, -0.005027468781918287, 0.015030880458652973, -0.008512486703693867]
# Focal length mismatch for sensor left-forward:
# x: 923.864075
# y: 919.140625
# vs
# x: 932.249573
# y: 931.254883
#
# Principal point mismatch for sensor left-forward:
# x: 958.96283
# y: 530.911133
# vs
# x: 966.628967
# y: 551.329163
#
# Distortion coefficients mismatch for sensor left-forward:
# [-0.029866665601730347, 0.011938659474253654, -0.0013153335312381387, -0.003152084769681096]
# vs
# [-0.021629629656672478, 0.00041008510743267834, 0.00834999792277813, -0.0055418480187654495]
# Focal length mismatch for sensor left-backward:
# x: 922.322571
# y: 936.466553
# vs
# x: 927.938721
# y: 927.114868
#
# Principal point mismatch for sensor left-backward:
# x: 970.084229
# y: 528.196411
# vs
# x: 960.051208
# y: 554.815552
#
# Distortion coefficients mismatch for sensor left-backward:
# [-0.03139149397611618, 0.006698529701679945, 0.0033498271368443966, -0.005085546523332596]
# vs
# [-0.020712440833449364, 0.0019378609722480178, 0.0054672178812325, -0.003786252113059163]
# Focal length mismatch for sensor right-forward:
# x: 922.461426
# y: 917.67334
# vs
# x: 927.88562
# y: 926.840088
#
# Principal point mismatch for sensor right-forward:
# x: 953.954956
# y: 525.448547
# vs
# x: 963.594727
# y: 559.030457
#
# Distortion coefficients mismatch for sensor right-forward:
# [-0.029843345284461975, 0.012181737460196018, -0.004851634614169598, -0.00109731568954885]
# vs
# [-0.019750550389289856, 0.0019046469824388623, 0.0068604107946157455, -0.005098266992717981]
# Focal length mismatch for sensor front-forward:
# x: 1561.50891
# y: 1545.7926
# vs
# x: 1580.78931
# y: 1579.11841
#
# Principal point mismatch for sensor front-forward:
# x: 964.04895
# y: 539.029785
# vs
# x: 953.048
# y: 524.137
#
# Distortion coefficients mismatch for sensor front-forward:
# [0.03164518624544144, -0.16437308490276337, 0.221182718873024, -0.25166845321655273]
# vs
# [0.018585210666060448, -0.07659496366977692, 0.21967829763889313, -0.3790492117404938]
# ////////////////////////////////mono////////////////////////////////
# ////////////////////////////////spoon////////////////////////////////
# ////////////////////////////////ebro////////////////////////////////
# ////////////////////////////////elbe////////////////////////////////
# ////////////////////////////////colorado////////////////////////////////
# ////////////////////////////////forest////////////////////////////////
# ////////////////////////////////lbn00002////////////////////////////////
# ////////////////////////////////lbn00003////////////////////////////////
# In assert_equality_camera_intrinsics for lbn00003 got error:
# Focal length mismatch for sensor right-backward:
# x: 917.463562
# y: 915.899109
# vs
# x: 926.82666
# y: 926.089478
#
# Principal point mismatch for sensor right-backward:
# x: 953.512817
# y: 527.321899
# vs
# x: 970.711426
# y: 555.199707
#
# Distortion coefficients mismatch for sensor right-backward:
# [-0.018754199147224426, 0.008614083752036095, 0.0020211536902934313, -0.003005875274538994]
# vs
# [-0.020015660673379898, 0.0005817040801048279, 0.007580492179840803, -0.005454719997942448]
# Focal length mismatch for sensor left-forward:
# x: 931.617188
# y: 931.733154
# vs
# x: 931.029846
# y: 930.11731
#
# Principal point mismatch for sensor left-forward:
# x: 957.241516
# y: 530.295837
# vs
# x: 963.804321
# y: 552.311707
#
# Distortion coefficients mismatch for sensor left-forward:
# [-0.024891261011362076, 0.0060843899846076965, -0.0002619877632241696, -0.0010360284941270947]
# vs
# [-0.021850770339369774, 0.0017513299826532602, 0.0046452721580863, -0.002942634979262948]
# Focal length mismatch for sensor left-backward:
# x: 926.716125
# y: 928.632385
# vs
# x: 907.477417
# y: 906.516968
#
# Principal point mismatch for sensor left-backward:
# x: 953.464844
# y: 527.735046
# vs
# x: 966.12207
# y: 553.451904
#
# Distortion coefficients mismatch for sensor left-backward:
# [-0.020839093253016472, 0.003194461576640606, 0.0002167893690057099, -0.0006177983013913035]
# vs
# [-0.011542930267751217, -0.004332087002694607, 0.01646965928375721, -0.011378680355846882]
# Focal length mismatch for sensor right-forward:
# x: 929.175232
# y: 929.212769
# vs
# x: 927.339722
# y: 926.366882
#
# Principal point mismatch for sensor right-forward:
# x: 954.439209
# y: 530.010864
# vs
# x: 966.128723
# y: 553.310242
#
# Distortion coefficients mismatch for sensor right-forward:
# [-0.021243920549750328, 0.0018968803342431784, 0.0022488588001579046, -0.0016972206067293882]
# vs
# [-0.021549679338932037, 0.004396914038807154, -9.203560330206528e-05, -0.000369728310033679]
# Focal length mismatch for sensor front-forward:
# x: 1584.22009
# y: 1580.8335
# vs
# x: 1570.3468
# y: 1568.65137
#
# Principal point mismatch for sensor front-forward:
# x: 964.385
# y: 544.460266
# vs
# x: 946.749084
# y: 514.764282
#
# Distortion coefficients mismatch for sensor front-forward:
# [0.012675744481384754, -0.05415811762213707, 0.0867675244808197, -0.14854122698307037]
# vs
# [0.01639961078763008, -0.053574901074171066, 0.1292629987001419, -0.2482800930738449]
# ////////////////////////////////muswell////////////////////////////////
# ////////////////////////////////napo////////////////////////////////
# ////////////////////////////////tower_av////////////////////////////////
# ////////////////////////////////xev00001////////////////////////////////
# ////////////////////////////////FME10001////////////////////////////////

# %%
problematic_vehicles
# Out:
# ['avon',
#  'beni',
#  'brizo',
#  'congo',
#  'ebisu',
#  'ganges',
#  'hudson',
#  'nammu',
#  'neptune',
#  'nereus',
#  'oya',
#  'po',
#  'poseidon',
#  'sedna',
#  'shire',
#  'thames',
#  'mekong',
#  'lbn00003']
